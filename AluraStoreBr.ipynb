# %% [markdown]
# ### Importação dos dados

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_1.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_4.csv"

loja = pd.read_csv(url)
loja2 = pd.read_csv(url2)
loja3 = pd.read_csv(url3)
loja4 = pd.read_csv(url4)

loja.head()
# Out:
#                  Produto Categoria do Produto    Preço      Frete  \
# 0     Assistente virtual          eletronicos   219.08   9.249790
# 1         Mesa de jantar               moveis   256.35  11.234305
# 2      Jogo de tabuleiro           brinquedos   279.51  21.262681
# 3            Micro-ondas     eletrodomesticos  1009.99  54.667344
# 4  Cadeira de escritório               moveis   446.99  26.964689
#
#   Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0     16/01/2021     Pedro Gomes              SP                    4
# 1     18/05/2022  Beatriz Moraes              RJ                    1
# 2     15/03/2021      João Souza              DF                    1
# 3     03/05/2022      João Souza              RS                    4
# 4     07/11/2020   Larissa Alves              MG                    5
#
#   Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0    cartao_credito                       8 -22.19 -48.79
# ...

# %% [markdown]
# #1. Análise do faturamento

# %%
# Faturamento total = soma de (Preço + Frete)

faturamento_loja1 = (loja['Preço'] + loja['Frete']).sum()
faturamento_loja2 = (loja2['Preço'] + loja2['Frete']).sum()
faturamento_loja3 = (loja3['Preço'] + loja3['Frete']).sum()
faturamento_loja4 = (loja4['Preço'] + loja4['Frete']).sum()

# Exibir resultados
print(f'Faturamento total Loja 1: R$ {faturamento_loja1:.2f}')
print(f'Faturamento total Loja 2: R$ {faturamento_loja2:.2f}')
print(f'Faturamento total Loja 3: R$ {faturamento_loja3:.2f}')
print(f'Faturamento total Loja 4: R$ {faturamento_loja4:.2f}')
# Out:
# Faturamento total Loja 1: R$ 1616347.09
# Faturamento total Loja 2: R$ 1567773.22
# Faturamento total Loja 3: R$ 1542047.69
# Faturamento total Loja 4: R$ 1458253.46

# %%
import matplotlib.pyplot as plt

# Nomes das lojas
lojas = ['Loja 1', 'Loja 2', 'Loja 3', 'Loja 4']

# Faturamentos
faturamentos = [faturamento_loja1, faturamento_loja2, faturamento_loja3, faturamento_loja4]

# Criando o gráfico de barras
plt.figure(figsize=(8,5))
plt.bar(lojas, faturamentos, color='skyblue')

# Adicionando título e rótulos
plt.title('Faturamento Total por Loja')
plt.xlabel('Lojas')
plt.ylabel('Faturamento (R$)')

# Adicionando os valores acima das barras
for i, valor in enumerate(faturamentos):
    plt.text(i, valor + 100, f'R$ {valor:.2f}', ha='center', fontsize=9)

# Exibindo o gráfico
plt.show()

# %% [markdown]
# # 2. Vendas por Categoria

# %%
# Contando a quantidade de vendas por categoria
categorias_populares = loja['Categoria do Produto'].value_counts()

# Exibindo os resultados
print(categorias_populares)
# Out:
# Categoria do Produto
# moveis                   465
# eletronicos              448
# brinquedos               324
# eletrodomesticos         312
# esporte e lazer          284
# instrumentos musicais    182
# livros                   173
# utilidades domesticas    171
# Name: count, dtype: int64

# %%
# Criando o gráfico de barras
plt.figure(figsize=(8,5))
categorias_populares.plot(kind='bar', color='salmon')

# Adicionando título e rótulos
plt.title('Categorias Mais Populares')
plt.xlabel('Categoria')
plt.ylabel('Número de Vendas')

# Exibindo o gráfico
plt.show()

# %% [markdown]
# # 3. Média de Avaliação das Lojas

# %%
# Média das avaliações por loja
media_avaliacao_loja1 = loja['Avaliação da compra'].mean()
media_avaliacao_loja2 = loja2['Avaliação da compra'].mean()
media_avaliacao_loja3 = loja3['Avaliação da compra'].mean()
media_avaliacao_loja4 = loja4['Avaliação da compra'].mean()

# Exibir resultados
print(f'Média de avaliação Loja 1: {media_avaliacao_loja1:.2f}')
print(f'Média de avaliação Loja 2: {media_avaliacao_loja2:.2f}')
print(f'Média de avaliação Loja 3: {media_avaliacao_loja3:.2f}')
print(f'Média de avaliação Loja 4: {media_avaliacao_loja4:.2f}')
# Out:
# Média de avaliação Loja 1: 3.98
# Média de avaliação Loja 2: 4.04
# Média de avaliação Loja 3: 4.05
# Média de avaliação Loja 4: 4.00

# %%
# Médias de avaliação
avaliacoes = [media_avaliacao_loja1, media_avaliacao_loja2, media_avaliacao_loja3, media_avaliacao_loja4]

# Criando o gráfico de barras
plt.figure(figsize=(8,5))
plt.bar(lojas, avaliacoes, color='lightgreen')

# Adicionando título e rótulos
plt.title('Média de Avaliação por Loja')
plt.xlabel('Lojas')
plt.ylabel('Média de Avaliação')

# Exibindo os valores acima das barras
for i, valor in enumerate(avaliacoes):
    plt.text(i, valor + 0.05, f'{valor:.2f}', ha='center', fontsize=9)

# Exibindo o gráfico
plt.show()

# %% [markdown]
# # 4. Produtos Mais e Menos Vendidos

# %%
# Contar a quantidade de vendas de cada produto
vendas_por_produto = loja.groupby('Produto')['Quantidade de parcelas'].sum().sort_values(ascending=False)

# Exibindo os produtos mais e menos vendidos
print("Produtos mais vendidos:")
print(vendas_por_produto.head())

print("\nProdutos menos vendidos:")
print(vendas_por_produto.tail())
# Out:
# Produtos mais vendidos:
# Produto
# Secadora de roupas    214
# TV Led UHD 4K         196
# Cômoda                188
# Impressora            182
# Bicicleta             178
# Name: Quantidade de parcelas, dtype: int64
#
# Produtos menos vendidos:
# Produto
# Corda de pular    100
# Tablet ABXY        99
# Dinossauro Rex     94
# Mochila            90
# Celular ABXY       78
# Name: Quantidade de parcelas, dtype: int64

# %%
# Concatenando os dois conjuntos (produtos mais vendidos e menos vendidos) para o gráfico
produtos_para_pizza = pd.concat([produtos_mais_vendidos, produtos_menos_vendidos])

# Criando o gráfico de pizza
plt.figure(figsize=(8,8))
plt.pie(produtos_para_pizza, labels=produtos_para_pizza.index, autopct='%1.1f%%', startangle=90, colors=['lightblue', 'lightgreen', 'lightcoral', 'lightskyblue', 'lightpink', 'lightyellow', 'lightgray', 'lightseagreen', 'peachpuff', 'mistyrose'])

# Adicionando título
plt.title('Distribuição dos Produtos Mais e Menos Vendidos')

# Exibindo o gráfico
plt.show()

# %% [markdown]
# # 5. Frete Médio por Loja

# %%
# Calculando o frete médio por loja
frete_medio_loja1 = loja['Frete'].mean()
frete_medio_loja2 = loja2['Frete'].mean()
frete_medio_loja3 = loja3['Frete'].mean()
frete_medio_loja4 = loja4['Frete'].mean()

# Organizando os valores em uma lista para fácil visualização
fretes = [frete_medio_loja1, frete_medio_loja2, frete_medio_loja3, frete_medio_loja4]
lojas = ['Loja 1', 'Loja 2', 'Loja 3', 'Loja 4']

# Exibindo o frete médio por loja
for loja, frete in zip(lojas, fretes):
    print(f"{loja}: {frete:.2f} reais")
# Out:
# Loja 1: 34.69 reais
# Loja 2: 33.62 reais
# Loja 3: 33.07 reais
# Loja 4: 31.28 reais

# %%
# Criando o gráfico de barras
plt.figure(figsize=(8,6))
plt.bar(lojas, fretes, color='lightcoral')

# Adicionando título e rótulos aos eixos
plt.title('Frete Médio por Loja')
plt.xlabel('Lojas')
plt.ylabel('Frete Médio (R$)')

# Exibindo o gráfico
plt.show()

# %% [markdown]
# #Relatório Final - Análise de Lojas para Venda
#
# Introdução
#
# Neste trabalho, realizei uma análise dos dados de quatro lojas com o objetivo de ajudar o Senhor João a decidir qual loja ele deve vender.
#  Foram avaliados fatores como faturamento, avaliação dos clientes, produtos mais e menos vendidos e o valor médio do frete.
#
# Desenvolvimento
#
# 1. Faturamento Total
#
# A Loja 1 foi a que apresentou o maior faturamento entre todas as lojas.
#
# 2. Média das Avaliações
#
# A Loja 4 teve a melhor média de avaliação dos clientes, indicando maior satisfação dos consumidores.
#
# A Loja 1, apesar de faturar mais, não teve a melhor avaliação.
#
# 3. Produtos Mais e Menos Vendidos
#
# Nas análises, vimos que algumas lojas vendem mais produtos variados, enquanto outras têm vendas mais concentradas em poucos produtos.
#
# 4. Frete Médio
#
# As lojas apresentaram valores de frete diferentes, mas nenhuma teve um frete tão alto a ponto de impactar muito negativamente.
#
# Conclusão
#
# Mesmo que a Loja 1 tenha o maior faturamento, ela não é a loja com a melhor avaliação dos clientes.
#  Além disso, vender a Loja 1 agora, enquanto ela ainda está em alta, pode ser a melhor estratégia para o Senhor João ganhar mais dinheiro com a venda.
#  Assim, recomendamos que o Senhor João venda a Loja 1.
#
# Essa decisão foi baseada no alto valor de mercado da Loja 1 e também considerando que a satisfação dos clientes já não é a melhor entre as lojas.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Carregar os dados
url1 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_1.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_4.csv"

loja1 = pd.read_csv(url1)
loja2 = pd.read_csv(url2)
loja3 = pd.read_csv(url3)
loja4 = pd.read_csv(url4)

#  Coluna indicando a loja
loja1['Loja'] = 'Loja 1'
loja2['Loja'] = 'Loja 2'
loja3['Loja'] = 'Loja 3'
loja4['Loja'] = 'Loja 4'

# Juntar todos os dados
dados = pd.concat([loja1, loja2, loja3, loja4], ignore_index=True)

# Plotar Gráfico de Dispersão (Scatter Plot) para todas as vendas
plt.figure(figsize=(12,8))
sns.scatterplot(data=dados, x='lon', y='lat', hue='Loja', palette='Set2')
plt.title('Distribuição Geográfica das Vendas por Loja')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.grid(True)
plt.legend(title='Lojas')
plt.show()

# Plotar um Heatmap para concentração de vendas
plt.figure(figsize=(10,8))
sns.kdeplot(
    data=dados, x='lon', y='lat',
    cmap="Reds", fill=True, thresh=0.05
)
plt.title('Heatmap de Concentração de Vendas')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.grid(True)
plt.show()
